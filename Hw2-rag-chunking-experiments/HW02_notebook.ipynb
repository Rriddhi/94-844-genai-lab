# %% [markdown]
# ### **Install Python Packages:**

# %%
# !pip install transformers==4.44.2 numpy==1.26.4 --break-system-packages
# !pip install pymilvus[milvus_lite]
# !pip install --upgrade setuptools --break-system-packages

# !pip install --force-reinstall -q \
    "sentence-transformers>=3.0" \
    "faiss-cpu" \
    "pymilvus" \
    "datasets" \
    "PyMuPDF" \
    "nltk"
# !pip install "pymilvus[model]"
# !pip install chromadb
# Out:
# Collecting transformers==4.44.2
#   Using cached transformers-4.44.2-py3-none-any.whl.metadata (43 kB)
# Collecting numpy==1.26.4
#   Using cached numpy-1.26.4-cp313-cp313-macosx_26_0_arm64.whl
# Requirement already satisfied: filelock in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from transformers==4.44.2) (3.25.2)
# Collecting huggingface-hub<1.0,>=0.23.2 (from transformers==4.44.2)
#   Using cached huggingface_hub-0.36.2-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from transformers==4.44.2) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from transformers==4.44.2) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from transformers==4.44.2) (2026.2.28)
# Requirement already satisfied: requests in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from transformers==4.44.2) (2.33.0)
# Requirement already satisfied: safetensors>=0.4.1 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from transformers==4.44.2) (0.7.0)
# Collecting tokenizers<0.20,>=0.19 (from transformers==4.44.2)
#   Using cached tokenizers-0.19.1.tar.gz (321 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: tqdm>=4.27 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from transformers==4.44.2) (4.67.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers==4.44.2) (2026.2.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers==4.44.2) (1.4.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers==4.44.2) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from requests->transformers==4.44.2) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from requests->transformers==4.44.2) (3.11)
# Requirement already satisfied: urllib3<3,>=1.26 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from requests->transformers==4.44.2) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from requests->transformers==4.44.2) (2026.2.25)
# Using cached transformers-4.44.2-py3-none-any.whl (9.5 MB)
# Using cached huggingface_hub-0.36.2-py3-none-any.whl (566 kB)
# Building wheels for collected packages: tokenizers
#   Building wheel for tokenizers (pyproject.toml) ... error
#   error: subprocess-exited-with-error
#
#   × Building wheel for tokenizers (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [104 lines of output]
#       Running `maturin pep517 build-wheel -i /opt/anaconda3/envs/gen-ai-lab2/bin/python3.13 --compatibility off`
#       Rust not found, installing into a temporary directory
#       Python reports SOABI: cpython-313-darwin
#       Computed rustc target triple: aarch64-apple-darwin
#       Installation directory: /Users/smridhipatwari/Library/Caches/puccinialin
#       Rustup already downloaded
#       Installing rust to /Users/smridhipatwari/Library/Caches/puccinialin/rustup
#       warn: It looks like you have an existing rustup settings file at:
#       warn: /Users/smridhipatwari/.rustup/settings.toml
#       warn: Rustup will install the default toolchain as specified in the settings file,
#       warn: instead of the one inferred from the default host triple.
#       info: profile set to minimal
#       info: default host triple is aarch64-apple-darwin
#       warn: Updating existing toolchain, profile choice will be ignored
#       info: syncing channel updates for stable-aarch64-apple-darwin
#       info: default toolchain set to stable-aarch64-apple-darwin
#       Checking if cargo is installed
#       cargo 1.94.0 (85eff7c80 2026-01-15)
#       ⚠️  Warning: `project.version` field is required in pyproject.toml unless it is present in the `project.dynamic` list
#       🍹 Building a mixed python/rust project
#       🔗 Found pyo3 bindings
#       🐍 Found CPython 3.13 at /opt/anaconda3/envs/gen-ai-lab2/bin/python3.13
#       📡 Using build options features, bindings from pyproject.toml
#       💻 Using `MACOSX_DEPLOYMENT_TARGET=11.0` for aarch64-apple-darwin by default
#          Compiling proc-macro2 v1.0.81
#          Compiling unicode-ident v1.0.12
#          Compiling autocfg v1.2.0
#          Compiling libc v0.2.153
#          Compiling target-lexicon v0.12.14
#          Compiling once_cell v1.19.0
#          Compiling cfg-if v1.0.0
#          Compiling memchr v2.7.2
#          Compiling cc v1.0.94
#          Compiling crossbeam-utils v0.8.19
#          Compiling fnv v1.0.7
#          Compiling ident_case v1.0.1
#          Compiling strsim v0.10.0
#          Compiling serde v1.0.198
#          Compiling portable-atomic v1.6.0
#          Compiling smallvec v1.13.2
#          Compiling regex-syntax v0.8.3
#          Compiling num-traits v0.2.18
#          Compiling aho-corasick v1.1.3
#          Compiling lock_api v0.4.11
#          Compiling pkg-config v0.3.30
#          Compiling rayon-core v1.12.1
#          Compiling either v1.11.0
#          Compiling parking_lot_core v0.9.9
#          Compiling onig_sys v69.8.1
#          Compiling crossbeam-epoch v0.9.18
#          Compiling getrandom v0.2.14
#          Compiling crossbeam-deque v0.8.5
#          Compiling regex-automata v0.4.6
#          Compiling quote v1.0.36
#          Compiling matrixmultiply v0.3.8
#          Compiling syn v2.0.60
#          Compiling memoffset v0.9.1
#          Compiling scopeguard v1.2.0
#          Compiling paste v1.0.14
#          Compiling heck v0.4.1
#          Compiling pyo3-build-config v0.21.2
#          Compiling rand_core v0.6.4
#          Compiling esaxx-rs v0.1.10
#          Compiling minimal-lexical v0.2.1
#          Compiling serde_json v1.0.116
#          Compiling rawpointer v0.2.1
#          Compiling thiserror v1.0.58
#          Compiling log v0.4.21
#          Compiling regex v1.10.4
#          Compiling lazy_static v1.4.0
#          Compiling unicode-width v0.1.11
#          Compiling utf8parse v0.2.1
#          Compiling ppv-lite86 v0.2.17
#          Compiling anstyle-parse v0.2.3
#          Compiling console v0.15.8
#          Compiling darling_core v0.20.8
#          Compiling rand_chacha v0.3.1
#          Compiling pyo3-macros-backend v0.21.2
#          Compiling nom v7.1.3
#          Compiling pyo3-ffi v0.21.2
#          Compiling pyo3 v0.21.2
#          Compiling parking_lot v0.12.1
#          Compiling serde_derive v1.0.198
#       error: failed to run custom build command for `pyo3-ffi v0.21.2`
#
#       Caused by:
#         process didn't exit successfully: `/private/var/folders/fw/s14j4g194pg8yvcdyx0fg43m0000gn/T/pip-install-uv0quuss/tokenizers_712ee08d29d44c599e90846f45bf5666/bindings/python/target/release/build/pyo3-ffi-60a30d4031ec99b1/build-script-build` (exit status: 1)
#         --- stdout
#         cargo:rerun-if-env-changed=PYO3_CROSS
#         cargo:rerun-if-env-changed=PYO3_CROSS_LIB_DIR
#         cargo:rerun-if-env-changed=PYO3_CROSS_PYTHON_VERSION
#         cargo:rerun-if-env-changed=PYO3_CROSS_PYTHON_IMPLEMENTATION
#         cargo:rerun-if-env-changed=PYO3_PRINT_CONFIG
#         cargo:rerun-if-env-changed=PYO3_USE_ABI3_FORWARD_COMPATIBILITY
#
#         --- stderr
#         error: the configured Python interpreter version (3.13) is newer than PyO3's maximum supported version (3.12)
#         = help: please check if an updated version of PyO3 is available. Current version: 0.21.2
#         = help: set PYO3_USE_ABI3_FORWARD_COMPATIBILITY=1 to suppress this check and build anyway using the stable ABI
#       warning: build failed, waiting for other jobs to finish...
#       💥 maturin failed
#         Caused by: Failed to build a native library through cargo
#         Caused by: Cargo build finished with "exit status: 101": `env -u CARGO MACOSX_DEPLOYMENT_TARGET="11.0" PYO3_BUILD_EXTENSION_MODULE="1" PYO3_ENVIRONMENT_SIGNATURE="cpython-3.13-64bit" PYO3_PYTHON="/opt/anaconda3/envs/gen-ai-lab2/bin/python3.13" PYTHON_SYS_EXECUTABLE="/opt/anaconda3/envs/gen-ai-lab2/bin/python3.13" "cargo" "rustc" "--profile" "release" "--features" "pyo3/extension-module" "--message-format" "json-render-diagnostics" "--manifest-path" "/private/var/folders/fw/s14j4g194pg8yvcdyx0fg43m0000gn/T/pip-install-uv0quuss/tokenizers_712ee08d29d44c599e90846f45bf5666/bindings/python/Cargo.toml" "--lib" "--" "-C" "link-arg=-undefined" "-C" "link-arg=dynamic_lookup" "-C" "link-args=-Wl,-install_name,@rpath/tokenizers.tokenizers.cpython-313-darwin.so"`
#       Error: command ['maturin', 'pep517', 'build-wheel', '-i', '/opt/anaconda3/envs/gen-ai-lab2/bin/python3.13', '--compatibility', 'off'] returned non-zero exit status 1
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for tokenizers
# Failed to build tokenizers
# error: failed-wheel-build-for-install
#
# × Failed to build installable wheels for some pyproject.toml based projects
# ╰─> tokenizers
# zsh:1: no matches found: pymilvus[milvus_lite]
# Requirement already satisfied: setuptools in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (81.0.0)
# Collecting setuptools
#   Using cached setuptools-82.0.1-py3-none-any.whl.metadata (6.5 kB)
# Using cached setuptools-82.0.1-py3-none-any.whl (1.0 MB)
# Installing collected packages: setuptools
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 81.0.0
#     Uninstalling setuptools-81.0.0:
#       Successfully uninstalled setuptools-81.0.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torch 2.11.0 requires setuptools<82, but you have setuptools 82.0.1 which is incompatible.
# Successfully installed setuptools-82.0.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# googleapis-common-protos 1.73.0 requires protobuf!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2, but you have protobuf 7.34.1 which is incompatible.
# opentelemetry-proto 1.40.0 requires protobuf<7.0,>=5.0, but you have protobuf 7.34.1 which is incompatible.
# Requirement already satisfied: pymilvus[model] in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (2.6.10)
# Requirement already satisfied: setuptools>69 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from pymilvus[model]) (81.0.0)
# Requirement already satisfied: grpcio!=1.68.0,!=1.68.1,!=1.69.0,!=1.70.0,!=1.70.1,!=1.71.0,!=1.72.1,!=1.73.0,>=1.66.2 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from pymilvus[model]) (1.78.0)
# Requirement already satisfied: orjson>=3.10.15 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from pymilvus[model]) (3.11.7)
# Requirement already satisfied: protobuf>=5.27.2 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from pymilvus[model]) (7.34.1)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.1 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from pymilvus[model]) (1.2.2)
# Requirement already satisfied: pandas>=1.2.4 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from pymilvus[model]) (3.0.1)
# Requirement already satisfied: cachetools>=5.0.0 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from pymilvus[model]) (7.0.5)
# Requirement already satisfied: requests>=2.20.0 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from pymilvus[model]) (2.33.0)
# Requirement already satisfied: pymilvus.model>=0.3.0 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from pymilvus[model]) (0.3.2)
# Requirement already satisfied: typing-extensions~=4.12 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from grpcio!=1.68.0,!=1.68.1,!=1.69.0,!=1.70.0,!=1.70.1,!=1.71.0,!=1.72.1,!=1.73.0,>=1.66.2->pymilvus[model]) (4.15.0)
# Requirement already satisfied: numpy>=1.26.0 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from pandas>=1.2.4->pymilvus[model]) (2.4.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from pandas>=1.2.4->pymilvus[model]) (2.9.0.post0)
# Requirement already satisfied: transformers>=4.36.0 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from pymilvus.model>=0.3.0->pymilvus[model]) (5.3.0)
# Requirement already satisfied: onnxruntime in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from pymilvus.model>=0.3.0->pymilvus[model]) (1.24.4)
# Requirement already satisfied: scipy>=1.10.0 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from pymilvus.model>=0.3.0->pymilvus[model]) (1.17.1)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas>=1.2.4->pymilvus[model]) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from requests>=2.20.0->pymilvus[model]) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from requests>=2.20.0->pymilvus[model]) (3.11)
# Requirement already satisfied: urllib3<3,>=1.26 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from requests>=2.20.0->pymilvus[model]) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from requests>=2.20.0->pymilvus[model]) (2026.2.25)
# Requirement already satisfied: huggingface-hub<2.0,>=1.3.0 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from transformers>=4.36.0->pymilvus.model>=0.3.0->pymilvus[model]) (1.8.0)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from transformers>=4.36.0->pymilvus.model>=0.3.0->pymilvus[model]) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from transformers>=4.36.0->pymilvus.model>=0.3.0->pymilvus[model]) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from transformers>=4.36.0->pymilvus.model>=0.3.0->pymilvus[model]) (2026.2.28)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from transformers>=4.36.0->pymilvus.model>=0.3.0->pymilvus[model]) (0.22.2)
# Requirement already satisfied: typer in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from transformers>=4.36.0->pymilvus.model>=0.3.0->pymilvus[model]) (0.24.1)
# Requirement already satisfied: safetensors>=0.4.3 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from transformers>=4.36.0->pymilvus.model>=0.3.0->pymilvus[model]) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from transformers>=4.36.0->pymilvus.model>=0.3.0->pymilvus[model]) (4.67.3)
# Requirement already satisfied: filelock>=3.10.0 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from huggingface-hub<2.0,>=1.3.0->transformers>=4.36.0->pymilvus.model>=0.3.0->pymilvus[model]) (3.25.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from huggingface-hub<2.0,>=1.3.0->transformers>=4.36.0->pymilvus.model>=0.3.0->pymilvus[model]) (2026.2.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.2 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from huggingface-hub<2.0,>=1.3.0->transformers>=4.36.0->pymilvus.model>=0.3.0->pymilvus[model]) (1.4.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from huggingface-hub<2.0,>=1.3.0->transformers>=4.36.0->pymilvus.model>=0.3.0->pymilvus[model]) (0.28.1)
# Requirement already satisfied: anyio in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers>=4.36.0->pymilvus.model>=0.3.0->pymilvus[model]) (4.13.0)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers>=4.36.0->pymilvus.model>=0.3.0->pymilvus[model]) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers>=4.36.0->pymilvus.model>=0.3.0->pymilvus[model]) (0.16.0)
# Requirement already satisfied: flatbuffers in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from onnxruntime->pymilvus.model>=0.3.0->pymilvus[model]) (25.12.19)
# Requirement already satisfied: sympy in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from onnxruntime->pymilvus.model>=0.3.0->pymilvus[model]) (1.14.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from sympy->onnxruntime->pymilvus.model>=0.3.0->pymilvus[model]) (1.3.0)
# Requirement already satisfied: click>=8.2.1 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from typer->transformers>=4.36.0->pymilvus.model>=0.3.0->pymilvus[model]) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from typer->transformers>=4.36.0->pymilvus.model>=0.3.0->pymilvus[model]) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from typer->transformers>=4.36.0->pymilvus.model>=0.3.0->pymilvus[model]) (14.3.3)
# Requirement already satisfied: annotated-doc>=0.0.2 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from typer->transformers>=4.36.0->pymilvus.model>=0.3.0->pymilvus[model]) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from rich>=12.3.0->typer->transformers>=4.36.0->pymilvus.model>=0.3.0->pymilvus[model]) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from rich>=12.3.0->typer->transformers>=4.36.0->pymilvus.model>=0.3.0->pymilvus[model]) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->transformers>=4.36.0->pymilvus.model>=0.3.0->pymilvus[model]) (0.1.2)
# Requirement already satisfied: chromadb in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (1.5.5)
# Requirement already satisfied: build>=1.0.3 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from chromadb) (1.4.1)
# Requirement already satisfied: pydantic>=2.0 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from chromadb) (2.12.5)
# Requirement already satisfied: pydantic-settings>=2.0 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from chromadb) (2.13.1)
# Requirement already satisfied: pybase64>=1.4.1 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from chromadb) (1.4.3)
# Requirement already satisfied: uvicorn>=0.18.3 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.42.0)
# Requirement already satisfied: numpy>=1.22.5 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from chromadb) (2.4.3)
# Requirement already satisfied: typing-extensions>=4.5.0 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from chromadb) (4.15.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from chromadb) (1.24.4)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from chromadb) (1.40.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from chromadb) (1.40.0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from chromadb) (1.40.0)
# Requirement already satisfied: tokenizers>=0.13.2 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from chromadb) (0.22.2)
# Requirement already satisfied: pypika>=0.48.9 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from chromadb) (0.51.1)
# Requirement already satisfied: tqdm>=4.65.0 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from chromadb) (4.67.3)
# Requirement already satisfied: overrides>=7.3.1 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from chromadb) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from chromadb) (1.78.0)
# Requirement already satisfied: bcrypt>=4.0.1 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from chromadb) (5.0.0)
# Requirement already satisfied: typer>=0.9.0 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from chromadb) (0.24.1)
# Requirement already satisfied: kubernetes>=28.1.0 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from chromadb) (35.0.0)
# Requirement already satisfied: tenacity>=8.2.3 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from chromadb) (9.1.4)
# Requirement already satisfied: pyyaml>=6.0.0 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from chromadb) (6.0.3)
# Requirement already satisfied: mmh3>=4.0.1 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from chromadb) (5.2.1)
# Requirement already satisfied: orjson>=3.9.12 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from chromadb) (3.11.7)
# Requirement already satisfied: httpx>=0.27.0 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from chromadb) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from chromadb) (14.3.3)
# Requirement already satisfied: jsonschema>=4.19.0 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from chromadb) (4.26.0)
# Requirement already satisfied: packaging>=24.0 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from build>=1.0.3->chromadb) (26.0)
# Requirement already satisfied: pyproject_hooks in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: anyio in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from httpx>=0.27.0->chromadb) (4.13.0)
# Requirement already satisfied: certifi in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from httpx>=0.27.0->chromadb) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from httpx>=0.27.0->chromadb) (1.0.9)
# Requirement already satisfied: idna in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from httpx>=0.27.0->chromadb) (3.11)
# Requirement already satisfied: h11>=0.16 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.16.0)
# Requirement already satisfied: attrs>=22.2.0 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from jsonschema>=4.19.0->chromadb) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from jsonschema>=4.19.0->chromadb) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from jsonschema>=4.19.0->chromadb) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from jsonschema>=4.19.0->chromadb) (0.30.0)
# Requirement already satisfied: six>=1.9.0 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from kubernetes>=28.1.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from kubernetes>=28.1.0->chromadb) (1.9.0)
# Requirement already satisfied: requests in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from kubernetes>=28.1.0->chromadb) (2.33.0)
# Requirement already satisfied: requests-oauthlib in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: urllib3!=2.6.0,>=1.24.2 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from kubernetes>=28.1.0->chromadb) (2.6.3)
# Requirement already satisfied: durationpy>=0.7 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: flatbuffers in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from onnxruntime>=1.14.1->chromadb) (25.12.19)
# Requirement already satisfied: protobuf in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from onnxruntime>=1.14.1->chromadb) (7.34.1)
# Requirement already satisfied: sympy in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from onnxruntime>=1.14.1->chromadb) (1.14.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from opentelemetry-api>=1.2.0->chromadb) (8.7.1)
# Requirement already satisfied: zipp>=3.20 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.23.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.73.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.40.0 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.40.0)
# Requirement already satisfied: opentelemetry-proto==1.40.0 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.40.0)
# Collecting protobuf (from onnxruntime>=1.14.1->chromadb)
#   Using cached protobuf-6.33.6-cp39-abi3-macosx_10_9_universal2.whl.metadata (593 bytes)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.61b0 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.61b0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from pydantic>=2.0->chromadb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from pydantic>=2.0->chromadb) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from pydantic>=2.0->chromadb) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from pydantic-settings>=2.0->chromadb) (1.2.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from rich>=10.11.0->chromadb) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from rich>=10.11.0->chromadb) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from tokenizers>=0.13.2->chromadb) (1.8.0)
# Requirement already satisfied: filelock>=3.10.0 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.25.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2026.2.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.2 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (1.4.2)
# Requirement already satisfied: click>=8.2.1 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from typer>=0.9.0->chromadb) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from typer>=0.9.0->chromadb) (0.0.4)
# Requirement already satisfied: httptools>=0.6.3 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.7.1)
# Requirement already satisfied: uvloop>=0.15.1 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.22.1)
# Requirement already satisfied: watchfiles>=0.20 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from requests->kubernetes>=28.1.0->chromadb) (3.4.6)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb) (3.3.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/anaconda3/envs/gen-ai-lab2/lib/python3.13/site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Using cached protobuf-6.33.6-cp39-abi3-macosx_10_9_universal2.whl (427 kB)
# Installing collected packages: protobuf
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 7.34.1
#     Uninstalling protobuf-7.34.1:
#       Successfully uninstalled protobuf-7.34.1
# Successfully installed protobuf-6.33.6

# %% [markdown]
# ### **Import Python Dependencies:**

# %%
import os
import sys
import json
import datetime
import huggingface_hub
import fitz
import nltk
import pymilvus
import transformers
import anthropic
import pandas as pd
import numpy as np

from sentence_transformers import SentenceTransformer
import chromadb

from nltk.tokenize import word_tokenize

from nltk.tokenize import sent_tokenize
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np


from typing import Literal, Protocol, TypeVar, Optional, Any, Callable
from io import StringIO
from dotenv import load_dotenv

from pymilvus import (
    utility,
    MilvusClient,
    FieldSchema,
    CollectionSchema,
    DataType,
    Collection,
    AnnSearchRequest,
    RRFRanker,
    connections,
)


from nltk.tokenize import sent_tokenize
nltk.download('punkt_tab')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /Users/smridhipatwari/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/smridhipatwari/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# ## **Define and retrieve environmental variables / secrets:**

# %%
load_dotenv()  # Load variables from .env file
ANTHROPIC_API_KEY = os.getenv("ANTHROPIC_API_KEY")

# %% [markdown]
# ## **Custom Functions**

# %% [markdown]
# ### *Chunker Functions*

# %%
def word_chunker(text, chunk_size=50, overlap=10):
        words = text.split()
        chunks = []
        i = 0
        while i < len(words):
            chunk = words[i:i + chunk_size]
            chunks.append(" ".join(chunk))
            i += chunk_size - overlap
        return chunks

# %%
# Create a chunker function to use a different chunking method
def sentence_chunker(text, chunk_size=5, overlap=2):
    sentences = sent_tokenize(text)
    chunks = []
    i = 0
    while i < len(sentences):
        chunk = sentences[i:i + chunk_size]
        chunks.append(" ".join(chunk))
        i += chunk_size - overlap
    return chunks

# %%
# Create a chunker function to use a different chunking method
# Simple token-based chunker with overlap
def token_chunker(text, chunk_size=100, overlap=20):
    tokens = word_tokenize(text)
    chunks = []
    i = 0
    
    while i < len(tokens):
        chunk = tokens[i:i + chunk_size]
        chunks.append(" ".join(chunk))
        i += chunk_size - overlap
        
    return chunks

# %%
# Create a chunker function to use a different chunking method

model = SentenceTransformer("all-MiniLM-L6-v2")

def semantic_chunker(text, similarity_threshold=0.7):
    sentences = sent_tokenize(text)
    
    if not sentences:
        return []
    
    embeddings = model.encode(sentences)
    
    chunks = []
    current_chunk = [sentences[0]]
    
    for i in range(1, len(sentences)):
        sim = cosine_similarity(
            [embeddings[i - 1]],
            [embeddings[i]]
        )[0][0]
        
        if sim < similarity_threshold:
            chunks.append(" ".join(current_chunk))
            current_chunk = [sentences[i]]
        else:
            current_chunk.append(sentences[i])
    
    if current_chunk:
        chunks.append(" ".join(current_chunk))
    
    return chunks
# Out:
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 6357.53it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %% [markdown]
# ### *Embedding Model Function*

# %%
def embedding_model(modelSelection: Literal["sentence_transformers"]):
    embedder = None  # always initialize first
    try:
        if modelSelection == "default":
            embedder = model.DefaultEmbeddingFunction() # This will download "all-MiniLM-L6-v2", a light weight model.

        if modelSelection == "sentence_transformers":
            embedder = model.dense.SentenceTransformerEmbeddingFunction(
                model_name='all-MiniLM-L6-v2', # Specify the model name
                device='cpu' # Specify the device to use, e.g., 'cpu' or 'cuda:0'
                )
    except Exception as e:
        print(f"An error occurred: {e}")
        raise
    return embedder

# %%
def encode_text(chunks: list[str], embedder: Callable):
  encodings = embedder(chunks)
  return encodings

# %%
def save_embeddings(embeddings, path="embeddings.json"):
    serializable = {
        "dense": [v.tolist() if isinstance(v, np.ndarray) else v
                  for v in embeddings["dense"]],
        "sparse": [
            {"indices": v.indices.tolist(), "values": v.data.tolist()}
            for v in embeddings["sparse"]
        ]
    }
    with open(path, "w") as f:
        json.dump(serializable, f)
    print(f"Saved to {path}")

# %%
def load_embeddings(path="embeddings.json"):
    with open(path, "r") as f:
        data = json.load(f)
    return {
        "dense": np.array(data["dense"]),
        "sparse": [
            {"indices": np.array(item["indices"]), "values": np.array(item["values"])}
            for item in data["sparse"]
        ]
    }
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ### *Vector Store Design and Usage Functions*
#
# ---

# %%
import chromadb
import numpy as np

def create_client(vectorStoreName: str, metric: str, vector_dimension: int = None):
    """
    Creates a persistent ChromaDB client and collection.
    vector_dimension is optional — ChromaDB infers it automatically.
    """
    client = chromadb.PersistentClient(path="./chroma_db")

    collection = client.get_or_create_collection(
        name=vectorStoreName,
        metadata={"hnsw:space": f"{metric}"}  # options: "cosine", "l2", "ip"
    )

    print(f"Collection '{vectorStoreName}' ready. Count: {collection.count()}")
    return client, collection


def insert_embeddings(collection, docs: list, embeddings: dict, ids: list = None):
    """
    Insert documents and their embeddings into ChromaDB.
    embeddings: dict with 'dense' key (from BGEM3EmbeddingFunction)
    """
    if ids is None:
        ids = [str(i) for i in range(len(docs))]

    dense_vectors = embeddings["dense"]
    if isinstance(dense_vectors, np.ndarray):
        dense_vectors = dense_vectors.tolist()

    collection.add(
        ids=ids,
        documents=docs,
        embeddings=dense_vectors
    )
    print(f"Inserted {len(docs)} documents.")


def query_collection(collection, query_embeddings: dict, n_results: int = 5):
    """
    Query the collection with a dense embedding vector.
    """
    dense_vector = query_embeddings["dense"]
    if isinstance(dense_vector, np.ndarray):
        dense_vector = dense_vector.tolist()

    results = collection.query(
        query_embeddings=dense_vector,
        n_results=n_results
    )
    return results

# %%
import chromadb
import numpy as np
import json
from collections import Counter
import matplotlib.pyplot as plt

def match_questions_to_documents(
    questions: list,
    question_embeddings: dict,
    collection,
    docs: list,
    n_results: int = 1,
    top_n: int = 30,
    save_path: str = "question_matches.json"
):
    dense_vectors = question_embeddings["dense"]
    if isinstance(dense_vectors, np.ndarray):
        dense_vectors = dense_vectors.tolist()

    print(f"Querying {len(questions)} questions against {collection.count()} documents...")

    results = collection.query(
        query_embeddings=dense_vectors,
        n_results=n_results,
        include=["documents", "distances", "metadatas"]
    )

    # 2. Attach most similar document to each question
    matched = []
    for i, question in enumerate(questions):
        matched.append({
            "question_id": i,
            "question": question,
            "matched_document": results["documents"][i][0],
            "matched_doc_id": results["ids"][i][0],
            "similarity_score": round(1 - results["distances"][i][0], 4)
        })

    # 3. Save results
    with open(save_path, "w") as f:
        json.dump(matched, f, indent=2)
    print(f"Saved {len(matched)} matches to {save_path}")

    # 4. Plot distribution
    doc_counts = Counter(m["matched_doc_id"] for m in matched)

    sorted_pairs = sorted(zip(doc_counts.values(), doc_counts.keys()), reverse=True)
    top_pairs = sorted_pairs[:top_n]
    counts_top, doc_ids_top = zip(*top_pairs)

    fig, axes = plt.subplots(1, 2, figsize=(20, 6))

    # Horizontal bar chart
    axes[0].barh(range(len(doc_ids_top)), counts_top, color="steelblue", edgecolor="white")
    axes[0].set_yticks(range(len(doc_ids_top)))
    axes[0].set_yticklabels(doc_ids_top, fontsize=8)
    axes[0].invert_yaxis()
    axes[0].set_xlabel("Number of Questions Matched")
    axes[0].set_ylabel("Document ID")
    axes[0].set_title(f"Top {top_n} Documents by Match Count")

    # Similarity score histogram
    scores = [m["similarity_score"] for m in matched]
    axes[1].hist(scores, bins=30, color="darkorange", edgecolor="white")
    axes[1].set_xlabel("Similarity Score")
    axes[1].set_ylabel("Number of Questions")
    axes[1].set_title("Distribution of Similarity Scores")

    plt.tight_layout()
    plt.savefig("question_doc_distribution.png", dpi=150)
    plt.show()
    print("Saved plot to question_doc_distribution.png")

    # Summary stats
    print(f"\n── Summary ──────────────────────────────")
    print(f"Total questions:       {len(questions)}")
    print(f"Unique docs matched:   {len(doc_counts)}")
    print(f"Most matched doc:      {doc_counts.most_common(1)[0]}")
    print(f"Avg similarity score:  {np.mean(scores):.4f}")
    print(f"Min similarity score:  {np.min(scores):.4f}")
    print(f"Max similarity score:  {np.max(scores):.4f}")

    return matched

# %% [markdown]
# ## *Pydantic Models for LLM Judge Demo*

# %%
from pydantic import BaseModel, Field, field_validator
from typing import List
from enum import IntEnum

from pydantic import BaseModel, Field, field_validator, model_validator
from typing import List, Optional
from enum import IntEnum
import re
import json
from huggingface_hub import InferenceClient

class LikertScore(IntEnum):
    STRONGLY_DISAGREE = 1
    DISAGREE = 2
    NEUTRAL = 3
    AGREE = 4
    STRONGLY_AGREE = 5

# ── Pricing per 1M tokens (input, output) in USD ──────────────────────────────
MODEL_PRICING = {
    # Mistral
    "mistralai/Mistral-7B-Instruct-v0.3":       (0.10,  0.10),
    "mistralai/Mixtral-8x7B-Instruct-v0.1":     (0.50,  0.50),
    "mistralai/Mistral-Nemo-Instruct-2407":      (0.10,  0.10),
    # Meta Llama
    "meta-llama/Llama-3.1-8B-Instruct":         (0.10,  0.10),
    "meta-llama/Llama-3.1-70B-Instruct":        (0.40,  0.40),
    "meta-llama/Llama-3.3-70B-Instruct":        (0.40,  0.40),
    # Qwen
    "Qwen/Qwen2.5-7B-Instruct":                 (0.10,  0.10),
    "Qwen/Qwen2.5-72B-Instruct":                (0.40,  0.40),
    "Qwen/Qwen2.5-Coder-32B-Instruct":          (0.20,  0.20),
    # Google
    "google/gemma-2-9b-it":                     (0.10,  0.10),
    "google/gemma-2-27b-it":                    (0.27,  0.27),
    # Claude
    "claude-sonnet-4-6":                (0.003,  0.015),  
    "claude-3-5-sonnet-20241022":       (0.003,  0.015),
    "claude-3-opus-20250729":           (0.015,  0.075),
    "claude-3-haiku-20240307":          (0.00080, 0.0024),
}



def get_token_cost(model_id: str, input_tokens: int, output_tokens: int) -> dict:
    """Calculate cost based on model pricing."""
    if model_id not in MODEL_PRICING:
        print(f"Warning: no pricing found for {model_id}, cost set to None")
        return {"input_tokens": input_tokens, "output_tokens": output_tokens,
                "total_tokens": input_tokens + output_tokens, "cost_usd": None}

    price_in, price_out = MODEL_PRICING[model_id]
    cost = (input_tokens * price_in / 1_000_000) + (output_tokens * price_out / 1_000_000)

    return {
        "model_id":       model_id,
        "input_tokens":   input_tokens,
        "output_tokens":  output_tokens,
        "total_tokens":   input_tokens + output_tokens,
        "cost_usd":       round(cost, 8),
        "cost_per_1m_in": price_in,
        "cost_per_1m_out": price_out,
    }

# ── Pydantic Models ────────────────────────────────────────────────────────────

class TokenUsage(BaseModel):
    model_id:        str
    input_tokens:    int
    output_tokens:   int
    total_tokens:    int
    cost_usd:        Optional[float] = None
    cost_per_1m_in:  Optional[float] = None
    cost_per_1m_out: Optional[float] = None

class DocumentRelevance(BaseModel):
    doc_id:               str
    document_snippet:     str
    relevance_score:      LikertScore
    relevance_rationale:  str

class QuestionRelevanceEval(BaseModel):
    question_id:       int
    question:          str
    construct:         str = Field(default="relevance")
    document_evals:    List[DocumentRelevance]
    overall_score:     LikertScore
    overall_rationale: str
    token_usage:       Optional[TokenUsage] = None

    @field_validator("document_evals")
    @classmethod
    def must_have_at_least_one(cls, v):
        if len(v) == 0:
            raise ValueError("Must have at least one document evaluation")
        return v

    @property
    def mean_score(self) -> float:
        return sum(d.relevance_score for d in self.document_evals) / len(self.document_evals)

    @property
    def score_distribution(self) -> dict:
        return {score.name: sum(1 for d in self.document_evals if d.relevance_score == score)
                for score in LikertScore}
# Out:
# /var/folders/fw/s14j4g194pg8yvcdyx0fg43m0000gn/T/ipykernel_1576/1155569569.py:82: UserWarning: Field name "construct" in "QuestionRelevanceEval" shadows an attribute in parent "BaseModel"
#   class QuestionRelevanceEval(BaseModel):

# %% [markdown]
# ## *Metric Functions for Evaluation (Section C)*

# %%
def evaluate_relevance_claude(
    question:     str,
    question_id:  int,
    matched_docs: list,
    api_key:      str,
    model_id:     str = "claude-sonnet-4-6",
    construct:    str = "relevance"
) -> QuestionRelevanceEval:

    client = Anthropic(api_key=api_key)

    docs_text = "\n\n".join([
        f"[Doc {d['matched_doc_id']}]: {d['matched_document']}"
        for d in matched_docs
    ])

    doc_template = ", ".join([
        f'{{"doc_id": "{d["matched_doc_id"]}", "document_snippet": "...", '
        f'"relevance_score": 0, "relevance_rationale": "..."}}'
        for d in matched_docs
    ])

    prompt = f"""You are evaluating the {construct} of retrieved documents to a question.

Question: {question}

Retrieved Documents:
{docs_text}

Score each document's {construct} on a 5-point Likert scale:
1 = Strongly Disagree (not {construct} at all)
2 = Disagree (mostly not {construct})
3 = Neutral (neither somewhat {construct} nor somewhat not {construct})
4 = Agree (mostly {construct})
5 = Strongly Agree (highly {construct})

Respond with ONLY a valid JSON object, no markdown, no extra text:
{{
  "question_id": {question_id},
  "question": {json.dumps(question)},
  "construct": "{construct}",
  "document_evals": [{doc_template}],
  "overall_score": 0,
  "overall_rationale": "<summary>"
}}

"overall_score" must be a single integer from 1 to 5. Do not average — pick the most representative score."""

    response = client.messages.create(
        model=model_id,
        max_tokens=1500,
        messages=[
            {"role": "user", "content": prompt}
        ]
    )

    raw = response.content[0].text.strip()

    # Strip markdown fences if present
    raw = re.sub(r"```(?:json)?\s*", "", raw).strip()

    # Extract JSON robustly
    json_match = re.search(r'\{.*\}', raw, re.DOTALL)
    if not json_match:
        raise ValueError(f"No JSON found in response:\n{raw}")

    parsed = json.loads(json_match.group())

    # Coerce overall_score to valid integer
    if "overall_score" in parsed:
        parsed["overall_score"] = min(5, max(1, round(parsed["overall_score"])))

    # ── Compute cost from usage metadata ──────────────────────────────────
    token_usage = TokenUsage(**get_token_cost(
        model_id=model_id,
        input_tokens=response.usage.input_tokens,
        output_tokens=response.usage.output_tokens,
    ))

    return QuestionRelevanceEval(**parsed, token_usage=token_usage)

# %%
def evaluate_precision_recall(
    matched: list,
    eval_results: list[QuestionRelevanceEval],
    relevance_threshold: LikertScore = LikertScore.AGREE,  # score >= 4 = relevant
) -> dict:
    """
    Precision: of all documents retrieved, how many were actually relevant?
    Recall:    of all relevant documents, how many were retrieved?

    matched:        output of match_questions_to_documents()
    eval_results:   list of QuestionRelevanceEval from evaluate_relevance_hf()
    relevance_threshold: minimum LikertScore to count as relevant (default: 4)
    """

    total_retrieved = 0
    total_relevant_retrieved = 0
    total_relevant = 0

    per_question = []

    for eval_result in eval_results:
        n_retrieved = len(eval_result.document_evals)
        n_relevant_retrieved = sum(
            1 for d in eval_result.document_evals
            if d.relevance_score >= relevance_threshold
        )
        # Recall denominator: treat all docs in collection as potential relevant pool
        # Use overall_score as a proxy — if overall >= threshold, at least 1 relevant doc exists
        n_relevant = max(n_relevant_retrieved, 1) if eval_result.overall_score >= relevance_threshold else n_relevant_retrieved

        precision = n_relevant_retrieved / n_retrieved if n_retrieved > 0 else 0.0
        recall    = n_relevant_retrieved / n_relevant  if n_relevant  > 0 else 0.0
        f1        = (2 * precision * recall) / (precision + recall) if (precision + recall) > 0 else 0.0

        per_question.append({
            "question_id":          eval_result.question_id,
            "question":             eval_result.question,
            "n_retrieved":          n_retrieved,
            "n_relevant_retrieved": n_relevant_retrieved,
            "precision":            round(precision, 4),
            "recall":               round(recall, 4),
            "f1":                   round(f1, 4),
            "mean_relevance_score": round(eval_result.mean_score, 4),
        })

        total_retrieved          += n_retrieved
        total_relevant_retrieved += n_relevant_retrieved
        total_relevant           += n_relevant

    # Macro averages (average of per-question scores)
    macro_precision = sum(q["precision"] for q in per_question) / len(per_question)
    macro_recall    = sum(q["recall"]    for q in per_question) / len(per_question)
    macro_f1        = sum(q["f1"]        for q in per_question) / len(per_question)

    # Micro averages (aggregate counts first, then divide)
    micro_precision = total_relevant_retrieved / total_retrieved if total_retrieved > 0 else 0.0
    micro_recall    = total_relevant_retrieved / total_relevant  if total_relevant  > 0 else 0.0
    micro_f1        = (2 * micro_precision * micro_recall) / (micro_precision + micro_recall) if (micro_precision + micro_recall) > 0 else 0.0

    summary = {
        "threshold":       relevance_threshold.name,
        "n_questions":     len(eval_results),
        "macro_precision": round(macro_precision, 4),
        "macro_recall":    round(macro_recall, 4),
        "macro_f1":        round(macro_f1, 4),
        "micro_precision": round(micro_precision, 4),
        "micro_recall":    round(micro_recall, 4),
        "micro_f1":        round(micro_f1, 4),
        "per_question":    per_question,
    }

    # Plot
    fig, axes = plt.subplots(1, 3, figsize=(18, 5))

    metrics = ["precision", "recall", "f1"]
    colors  = ["steelblue", "darkorange", "seagreen"]

    for ax, metric, color in zip(axes, metrics, colors):
        scores = [q[metric] for q in per_question]
        ax.hist(scores, bins=20, color=color, edgecolor="white")
        ax.axvline(np.mean(scores), color="black", linestyle="--", linewidth=1.5, label=f"mean={np.mean(scores):.2f}")
        ax.set_title(f"Per-Question {metric.capitalize()}")
        ax.set_xlabel(metric.capitalize())
        ax.set_ylabel("Number of Questions")
        ax.legend()

    plt.suptitle(f"Precision / Recall / F1  (threshold: {relevance_threshold.name} = {relevance_threshold})", fontsize=13)
    plt.tight_layout()
    plt.savefig("precision_recall.png", dpi=150)
    plt.show()

    print(f"\n── Summary (threshold ≥ {relevance_threshold.name}) ─────────────────")
    print(f"Macro  Precision: {macro_precision:.4f}  Recall: {macro_recall:.4f}  F1: {macro_f1:.4f}")
    print(f"Micro  Precision: {micro_precision:.4f}  Recall: {micro_recall:.4f}  F1: {micro_f1:.4f}")

    return summary

# %% [markdown]
# ### **Load CMU Policy Handbook PDF into the environment:**

# %%
doc = fitz.open("CMU Student Handbook 2023-24.pdf")

out = open("cmu_policy.txt", "wb") # create a text output

for page in doc: # iterate the document pages
    text = page.get_text().encode("utf8") # get plain text (is in UTF-8)
    out.write(text) # write text of page
    out.write(bytes((12,))) # write page delimiter (form feed 0x0C)
out.close()

# %% [markdown]
# # **Section A: Experimenting with Queries in a Standard Vectore Store**
#
#
# ## **Learning Objectives:**
# > [1] Know how to build and evaluate the information retrieval of a basic RAG system (with no LLM integration):
# >> * Understand how to tokenize a document: What does tokenization entail? How do we know what tokenizer model to use for this task?
# >> * Understand how to select and use a data chunking strategy to break up a document and to create embeddings (knowledge represetations) to use for retrieving information from the vector store that is relevant to the user queries.
# >> * Conduct query experiments and analyze the RAG information retrieval quality by assessing the information retrieved from the vector store in response to the queries.

# %% [markdown]
# ## *Chunk the text of the CMU Policy Handbook*

# %%
text_chunks = [] # create an empty list to store the text chunks.
doc_idxs = []    # create an empty list to store unique identifiers for the text chunks.
chunked_policy_df = pd.DataFrame() # create an empty dataframe to store the text chunks.

# %%
'''
1. Select a chunking strategy.
2. Chunk the text of the CMU Policy Handbook.
3. Assign a unique identifier to each chunk that represents the original page in the handbook where the chunk is located.

'''

for doc_idx, page in enumerate(doc):
    page_text = page.get_text("text") # this grabs the text from each page of the CMU policy handbook PDF.
    cur_text_chunks = word_chunker(page_text, chunk_size=50, overlap=10) # Chunker Selection == word chunker. Change this in Section B of your homework.
    text_chunks.extend(cur_text_chunks)
    doc_idxs.extend([doc_idx] * len(cur_text_chunks))

# %%
# ADD UNIQUE IDENTIFIER (to each chunk)
chunked_policy_df['page_id'] = doc_idxs # put the page_id for each chunk into a pandas dataframe. Note that the page_id identifies the page location in the original PDF of the text.

# %%
# ADD EACH CHUNK TO THE DATAFRAME:
chunked_policy_df['text'] =text_chunks  # put the chunked text into the dataframe.

# %%
chunked_policy_df # glance at the Dataframe to check for errors.
# Out:
#       page_id                                               text
# 0           0             1 The Word: Student Handbook 2023-2024
# 1           1  2 Welcome to The Word 2023-2024 The Word stude...
# 2           1  all students will reach their highest potentia...
# 3           1  of our university. To ensure you are knowledge...
# 4           1  community. We hope you will take advantage of ...
# ...       ...                                                ...
# 2610      294  295 Case-specific questions regarding timefram...
# 2611      295  296 Appendix: Student Resources • Center for S...
# 2612      295  https://www.cmu.edu/current-students/index.htm...
# 2613      296  297 • The HUB: https://www.cmu.edu/hub/ • Offi...
# 2614      296  Office for Institutional Equity and Title IX: ...
#
# [2615 rows x 2 columns]

# %%
len(chunked_policy_df['text'])
# Out:
# 2615

# %% [markdown]
# ## Select an Embedding Model

# %%
import transformers
from transformers import AlbertTokenizer
from pymilvus import model

# other options:
#model = SentenceTransformer('bert-base-nli-mean-tokens') # here we are selecting to use a Bert model on HuggingFace to create the embeddings.

embedder = embedding_model("sentence_transformers")
# Out:
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 14015.49it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %%
# save the text chunks of the CMU Policy Handbook to a list
docs = chunked_policy_df['text'].tolist()

# create embeddings from the text chunks of the CMU Policy Handbook:
embeddings = embedder.encode_documents(docs) # this might take a long time, if it does, that is not atypical especially if you're working on CPU (versus GPU)

# %%
# save the CMU Policy Handbook Embeddings:

save_embeddings({"dense": embeddings, "sparse": []}, path="cmu_handbook_embeddings.json")
# Out:
# Saved to cmu_handbook_embeddings.json

# %%
'''
If needed, use the function below to load the embeddings back into your notebook.
'''
embeddings = load_embeddings("cmu_handbook_embeddings.json")

# %% [markdown]
# ## *Design the Vector Store*
#
# **Tasks:**
# > Select a similarity, distance or clustering algorithm to use in the Vector Store.
#
# > Upload the embeddings of the chunked CMU Policy Handbook to the Vector Store.
#
# > Check that the vector store was properly created and working.

# %%
# Create the vector store
client, collection = create_client(vectorStoreName="hw02", metric="cosine")
# Out:
# Collection 'hw02' ready. Count: 2615

# %%
# upload the embeddings:
docs=chunked_policy_df['text']
insert_embeddings(collection, list(chunked_policy_df['text']), embeddings)
# Out:
# Inserted 2615 documents.

# %%
# Inspect the vector store
print(f"Collection name: {collection.name}")
print(f"Collection metadata: {collection.metadata}")
print(f"Number of documents in collection: {collection.count()}")
# Out:
# Collection name: hw02
# Collection metadata: {'hnsw:space': 'cosine'}
# Number of documents in collection: 2615

# %% [markdown]
# ## *Design the Query Experiment*
#
# **Tasks:**
# > Create Python objects that define the questions (`queries') that you will use in the experiment. Note: please use the questions provided to you in the Homework Assignment instructions.
#
# >> Encode these query objects and save them in the environment.
#
# > Select evaluation metrics to assess the quality of the information retrieved from the vector store.
#
# > Retrieve information from the vector store using the queries.
#
# > Measure the quality of the information retrieval using the evaluation metrics that you chose.

# %%
# Define the queries for the experiments
q1="What is the academic integrity policy?"
q2="How is cheating defined in the policy?"
q3="What is the policy for improper or illegal communications?"
q4="What are CMU’s quiet hours?"
q5= "Where are pets or animals allowed on CMU’s campus?"

# %%
# define the list of questions that you will submit to the vector store:
#questions=pd.Series([q1, q2, q3, q4, q5])

#
q01 = pd.Series([q1])
q02 = pd.Series([q2])
q03 = pd.Series([q3])
q04 = pd.Series([q4])
q05 = pd.Series([q5])

# %%
# Encode the queries for the experiments using the embedding model
question_embedding = embedder.encode_documents(q01.tolist())

# %%
question_embedding
# Out:
# [array([-3.73943225e-02,  9.98494998e-02, -3.68607417e-02, -3.51854265e-02,
#          2.37348061e-02, -1.70656275e-02, -3.40798721e-02, -8.68340358e-02,
#         -1.54793228e-03,  6.92967027e-02,  5.04572093e-02,  8.24571624e-02,
#         -3.37054208e-02, -2.73006968e-02, -9.46990624e-02,  1.80964712e-02,
#         -5.24988510e-02,  1.17457379e-02, -4.06726040e-02, -2.24045962e-02,
#          5.08646062e-03,  2.71296259e-02,  4.15171981e-02,  4.43458706e-02,
#         -3.75666879e-02, -4.56076302e-03, -3.13719781e-03, -5.42213283e-02,
#         -5.58070950e-02, -8.69289935e-02, -5.29440790e-02, -2.69563571e-02,
#          1.82095859e-02,  3.29573527e-02, -2.11109314e-02,  9.53177139e-02,
#          2.09778566e-02, -3.37007409e-03,  2.45418977e-02,  2.53806403e-03,
#         -2.58776639e-02, -2.88361683e-02, -3.16623226e-02,  3.73185277e-02,
#         -1.05607314e-02, -7.15818703e-02,  4.87464555e-02, -6.59105629e-02,
#          9.01939720e-03, -1.15874009e-02, -6.04182780e-02, -3.66622619e-02,
#          2.46269051e-02, -2.90803891e-03, -2.71028262e-02, -1.90515928e-02,
#          4.68985178e-03,  2.41045523e-02, -4.28823568e-02, -9.69923567e-03,
#          4.47692797e-02,  5.22574782e-02, -7.02284127e-02,  4.74818237e-02,
#          9.43134278e-02, -1.31337475e-02, -2.69747283e-02,  1.36029124e-02,
#         -8.45905673e-03,  9.75295156e-02, -6.14808686e-03, -1.00244887e-01,
#         -2.85424050e-02,  1.96757037e-02,  6.89473003e-02,  4.39680517e-02,
#         -1.94348842e-02,  3.08421943e-02,  9.12224501e-02, -3.88792381e-02,
#         -2.27184646e-04, -3.84005122e-02,  5.75252883e-02,  6.95777265e-03,
#          1.11363539e-02, -7.63867497e-02, -7.31110713e-03, -7.89524242e-02,
#          7.07188919e-02,  6.82130549e-03,  3.18553895e-02, -5.34743592e-02,
#          1.19006045e-01, -6.96840743e-03,  2.81274803e-02,  1.02838874e-02,
#         -1.54999709e-02, -8.33981112e-02,  2.00702585e-02,  4.43919078e-02,
#         -7.41375536e-02,  4.03730981e-02, -5.45739084e-02, -3.63820675e-03,
#         -2.54990477e-02, -3.03290505e-02,  5.19843660e-02, -7.47084944e-03,
#         -1.12192910e-02,  6.25236519e-03,  4.15534712e-02,  5.38425744e-02,
#          2.86350194e-02,  3.63710267e-03,  1.11357391e-01,  8.37074965e-03,
#         -1.04368422e-02,  5.42027280e-02,  4.93788645e-02, -3.64270210e-02,
#         -2.46971287e-02, -9.43682343e-03,  5.31656668e-02, -5.24916090e-02,
#         -5.47143556e-02, -1.13373578e-01, -6.65768087e-02, -7.52620323e-33,
#          3.10657006e-02,  1.13719434e-01, -5.28845862e-02,  5.37485257e-03,
#         -7.44047463e-02, -5.32702953e-02, -4.04218435e-02, -6.49720337e-03,
#         -5.27488254e-02,  3.73503268e-02,  3.27858701e-02,  8.86625797e-02,
#          2.22494174e-02,  6.86354935e-03,  5.92796989e-02,  5.23947068e-02,
#         -1.09059833e-01,  1.57336116e-01,  5.03253378e-02,  4.60699163e-02,
#          6.71482831e-02, -9.05582234e-02,  7.32493475e-02, -3.36641856e-02,
#          2.72256881e-02, -1.74326655e-02, -1.59981456e-02,  7.16809044e-03,
#          1.42348197e-03,  2.55146399e-02,  4.76722680e-02, -3.45160179e-02,
#          4.96993912e-03, -5.21948859e-02,  4.24357168e-02,  6.43869862e-02,
#         -3.30291167e-02,  1.87895708e-02,  3.71764693e-03,  3.03013753e-02,
#          4.22821902e-02, -2.39961911e-02,  8.72009099e-02,  2.10527033e-02,
#          5.14819659e-02,  5.01107611e-02, -1.60871795e-03, -4.36618924e-02,
#          2.43438054e-02,  3.91710224e-03,  6.14159089e-03, -4.73433174e-02,
#          1.18901785e-02, -3.27076949e-02, -2.53802408e-02,  2.36324109e-02,
#         -1.98299084e-02,  2.01470517e-02, -3.28214169e-02, -5.36658689e-02,
#          1.02940381e-01,  5.56400493e-02, -8.88616741e-02,  2.59217136e-02,
#         -1.26007088e-02,  6.15658164e-02, -1.10199958e-01, -5.99913485e-03,
#          1.03741273e-01, -1.16170071e-01, -3.98632921e-02, -1.94460843e-02,
#         -4.36021648e-02,  1.64149087e-02, -7.84354359e-02,  6.39601843e-03,
#         -1.00321129e-01, -2.58839242e-02,  7.63584673e-02, -1.47198457e-02,
#         -8.03911015e-02,  6.74647419e-03,  1.74699854e-02, -8.31313431e-02,
#         -7.29024857e-02, -1.95807740e-02,  4.21812274e-02,  9.72843468e-02,
#          8.95486027e-02,  2.93279383e-02, -1.30464872e-02, -5.62517643e-02,
#         -1.69643648e-02,  5.70072904e-02, -1.27784740e-02,  2.99788694e-33,
#          5.88496886e-02, -5.59125394e-02, -2.72914097e-02,  6.09892309e-02,
#         -1.58774710e-04,  6.78343466e-03, -1.39933708e-03,  9.34408512e-03,
#          7.44879842e-02, -4.74219881e-02, -5.27936928e-02, -7.22112730e-02,
#          5.29115349e-02,  2.35261153e-02,  3.34261507e-02, -5.41110076e-02,
#         -4.06683385e-02, -1.56719107e-02, -8.32640678e-02,  1.74571667e-02,
#          8.32853243e-02, -2.77105626e-02,  2.56444495e-02,  7.70388395e-02,
#          2.81039719e-02, -3.75699066e-02, -4.05524522e-02, -1.19747274e-01,
#          9.32779815e-03,  3.69077809e-02,  6.11570776e-02,  6.98360130e-02,
#         -3.44291776e-02,  4.90709543e-02, -6.56694397e-02, -4.62028496e-02,
#          8.09681788e-02,  8.10176954e-02, -3.12100630e-02,  1.63387274e-03,
#          9.87788066e-02,  6.17819764e-02, -7.83065856e-02,  1.67937782e-02,
#          3.98748554e-02, -1.64522473e-02, -2.04459354e-02,  7.29127675e-02,
#         -1.70535482e-02, -2.95203477e-02, -8.20638426e-03, -4.67175543e-02,
#          5.56809828e-02, -4.05150875e-02,  6.04525208e-02,  9.52350572e-02,
#          1.03280395e-02,  7.27796033e-02, -3.28663401e-02,  1.15609333e-01,
#         -2.64050462e-03,  2.13191006e-02, -8.91398042e-02,  5.69694526e-02,
#          3.68959717e-02,  2.54157986e-02, -6.09534048e-02,  3.83476093e-02,
#         -3.53470594e-02, -5.81306824e-03,  5.53201400e-02, -6.05002455e-02,
#         -4.51134471e-03, -1.25054829e-02, -2.06911545e-02,  2.64451988e-02,
#          2.19405331e-02, -9.69275087e-02, -4.97604311e-02,  6.46451712e-02,
#          2.20490620e-02, -8.36757421e-02,  2.65827775e-03,  4.73717116e-02,
#         -2.95093246e-02, -2.77039371e-02,  4.30331938e-02, -4.77866344e-02,
#         -4.30791192e-02, -3.80124040e-02, -7.13193491e-02, -1.08120687e-01,
#         -5.04552051e-02, -8.82140696e-02, -4.60959002e-02, -1.65195910e-08,
#          1.09643470e-02,  1.86608545e-02,  3.61251086e-02,  3.91901359e-02,
#         -2.07409170e-02, -5.62246703e-02, -3.48226503e-02, -8.45929459e-02,
#          3.53126526e-02, -5.41098230e-03,  2.37215217e-03,  2.90749185e-02,
#         -5.34336306e-02, -5.07961586e-02,  1.46946413e-02,  1.96959954e-02,
#         -1.21234683e-02,  9.72134620e-02, -3.24535705e-02,  4.06179428e-02,
#          3.80212627e-02, -7.02821165e-02, -1.58075057e-02, -9.09683108e-03,
#          5.10183685e-02,  6.34857193e-02,  4.86519225e-02,  6.02483191e-02,
#          2.07021870e-02,  4.61487062e-02, -2.22337265e-02,  3.05589894e-03,
#          5.65484390e-02, -1.96263269e-02, -1.74689833e-02,  4.85728635e-03,
#          1.99459419e-02, -3.08595528e-03,  7.86238983e-02, -4.14979979e-02,
#         -4.28362302e-02,  2.47331299e-02,  4.87001017e-02, -8.82394053e-03,
#          4.30444032e-02,  2.63638496e-02, -8.73096064e-02,  9.48289037e-02,
#         -1.03783747e-02,  2.08498165e-02, -1.77520234e-02, -3.02318558e-02,
#         -2.74185017e-02, -3.04879583e-02, -2.18107030e-02, -2.12880373e-02,
#          4.72315773e-02,  1.99602954e-02, -1.11052744e-01, -2.48773098e-02,
#          1.36725992e-01, -4.54542562e-02,  8.16524252e-02, -8.85897577e-02],
#        dtype=float32)]

# %%
# save the question embeddings:
#save_embeddings(question_embedding, path="q01_embeddings.json")
save_embeddings({"dense": question_embedding, "sparse": []}, path="q01_embeddings.json")
# Out:
# Saved to q01_embeddings.json

# %%
q01_embeddings = load_embeddings("q01_embeddings.json")

# %%
# Search the vector store and retrieve information using the queries
vs_search_results = query_collection(collection, q01_embeddings, n_results= 5)
vs_search_results
# Out:
# {'ids': [['1046', '1032', '2360', '106', '68']],
#  'embeddings': None,
#  'documents': [['involving alleged violations of the University Policy on Academic Integrity, the following procedures apply:',
#    'of the University Policy on Academic Integrity including cheating, plagiarism, and unauthorized assistance. • Academic Integrity Liaison: Each department designates an individual who is trained by the Office of Community Standards and Integrity to provide guidance to course instructors in cases of alleged violations of the University Policy on Academic',
#    'academic integrity of our community. The Word provides a list of policies students are expected to uphold and the process by which violations will be addressed. Policies and procedures may be established or amended as necessary during the course of the academic year, which will become effective immediately upon notification',
#    'when any student violates the University Policy on Academic Integrity including cheating, plagiarism and unauthorized assistance. Academic Integrity Policy Students at Carnegie Mellon are engaged in intellectual activity consistent with the highest standards of the academy. The relationship between students and instructors and their shared commitment to overarching standards of',
#    'Integrity Academic integrity refers to the implicit commitment that every member makes to all others in the community to practice those principles that underlie the mission of the university and define academic integrity. These are: honesty and good faith; clarity in the communication of core values; professional conduct of work;']],
#  'uris': None,
#  'included': ['metadatas', 'documents', 'distances'],
#  'data': None,
#  'metadatas': [[None, None, None, None, None]],
#  'distances': [[0.16541719436645508,
#    0.1932518482208252,
#    0.21508103609085083,
#    0.23774760961532593,
#    0.24159473180770874]]}

# %% [markdown]
# # **Section B: Experimenting with an Retrieved_Number ('Top K') Parameter and Alternative Chunking and Embedding Strategies.**
#
# ## **Learning Objectives:**
# > [1] [insert]
#
#
# ## **General Instructions:**
# > [1] Choose one of the five (5) questions from Section A to use in three (3) different experiments that you will run in this section, Section B.
#
# > [2] **Experiment 1:** Run the query you selected in a search of the vector store, varying the 'retrieved_number' or 'top_k' parameter according to the homework assignment instructions. Make sure to record the input and output from the vector store. You'll need this record to complete Part C.
#
# > [3] **Experiment 2:** Follow the steps in Section A for building a vector store BUT this time, choose a different **chunking** strategy, re-create the document embeddings for these new chunks, and upload to the new vector store. Then, submit your chosen query to the story, varying the 'retrieved_number' or 'top_k' parameter according to the homework assignment instructions, as you did in step_2, above. Make sure to record the input and output from the vector store. You'll need this record to complete Part C.
#
# > [4] **Experiment 3:** Follow the steps in Section A for building a vector store, while using the SAME chunking strategy that you used in Experiment 2, for this experiment 3, use the **embedding** strategy detailed below; with these embeddings (described below), upload them to the new vector store. Then, submit your chosen query to the story, varying the 'retrieved_number' or 'top_k' parameter according to the homework assignment instructions, as you did in step_2 and step_3, above. Make sure to record the input and output from the vector store. You'll need this record to complete Part C.
#
# >> Instead of using the CMU Policy Document chunks for your embeddings, instead, convert the list of questions provided to you (and posted to Canvas), convert those questions to embeddings and attached the CMU Policy Document chunks to questions that are relevant to the Policy Document Chunk. Upload the `policy question embeddings` and the attached metadata (e.g. the CMU Policy Document Chunks) to the vector store. Then, repeat the experiment but using this vector store design. Record the input and output from the vector store.
#
#
#
# > **Reminder**: Record the input (query) and output (vector store responses) of each experiment. You'll need this record to complete Section C.

# %% [markdown]
# ## *Design the Query Experiment*
#
# **Tasks:**
# > [1] Create Python objects that define the questions (`queries') that you will use in the experiment. Note: please use the questions provided to you in the Homework Assignment instructions.
#
# >> [1.a]Encode these query objects and save them in the environment.
#
# > [2] Retrieve information from the vector store using the queries.
#
# > [3] Save the retrieved information in the Google spreadsheet (a template is provided in the Homework Assignment Document posted to Canvas)

# %% [markdown]
# ## *Experiment B.I: Varying the Retrieved_Number ('Top_K') Parameter.*

# %%
# Define the query chosen for the experiment.
query = "What is the academic integrity policy?"

# %%
# Encode the query for the experiment using the embedding model.
query_embedding = embedder.encode_documents([query])

# %%
# Search the vector store [varying the retrieved_numer (top_k) Parameter] and retrieve information using the queries
retrieved_number = 5
vs_search_results = query_collection(collection, q01_embeddings, n_results= retrieved_number)
print(f"Top {retrieved_number} search results:")
for i in range(retrieved_number):
    print(f"Result {i+1}:")
    print(f"Document ID: {vs_search_results['ids'][0][i]}")
    print(f"Document Text: {vs_search_results['documents'][0][i]}")
    print(f"Similarity Score: {1 - vs_search_results['distances'][0][i]:.4f}")
    print("-" * 50)
# Out:
# Top 5 search results:
# Result 1:
# Document ID: 1046
# Document Text: involving alleged violations of the University Policy on Academic Integrity, the following procedures apply:
# Similarity Score: 0.8346
# --------------------------------------------------
# Result 2:
# Document ID: 1032
# Document Text: of the University Policy on Academic Integrity including cheating, plagiarism, and unauthorized assistance. • Academic Integrity Liaison: Each department designates an individual who is trained by the Office of Community Standards and Integrity to provide guidance to course instructors in cases of alleged violations of the University Policy on Academic
# Similarity Score: 0.8067
# --------------------------------------------------
# Result 3:
# Document ID: 2360
# Document Text: academic integrity of our community. The Word provides a list of policies students are expected to uphold and the process by which violations will be addressed. Policies and procedures may be established or amended as necessary during the course of the academic year, which will become effective immediately upon notification
# Similarity Score: 0.7849
# --------------------------------------------------
# Result 4:
# Document ID: 106
# Document Text: when any student violates the University Policy on Academic Integrity including cheating, plagiarism and unauthorized assistance. Academic Integrity Policy Students at Carnegie Mellon are engaged in intellectual activity consistent with the highest standards of the academy. The relationship between students and instructors and their shared commitment to overarching standards of
# Similarity Score: 0.7623
# --------------------------------------------------
# Result 5:
# Document ID: 68
# Document Text: Integrity Academic integrity refers to the implicit commitment that every member makes to all others in the community to practice those principles that underlie the mission of the university and define academic integrity. These are: honesty and good faith; clarity in the communication of core values; professional conduct of work;
# Similarity Score: 0.7584
# --------------------------------------------------

# %%
# Save the input and output from the vector store.
input_output = {
    "query": query,
    "retrieved_number": retrieved_number,
    "results": [
        {
            "document_id": vs_search_results['ids'][0][i],
            "document_text": vs_search_results['documents'][0][i],
            "similarity_score": round(1 - vs_search_results['distances'][0][i], 4)
        }
        for i in range(retrieved_number)
    ]
}
with open("vector_store_results.json", "w") as f:
    json.dump(input_output, f, indent=2)
print("Saved vector store results to vector_store_results.json")
# Out:
# Saved vector store results to vector_store_results.json

# %% [markdown]
# ## *Experiment B.II: Using an Alternative Chunking Strategy.*

# %%
# Choose a DIFFERENT chunking strategy AND remake the vector store using these new chunks.
# Search the vector store [varying the retrieved_numer (top_k) Parameter] and retrieve information using the queries

for doc_idx, page in enumerate(doc):
    page_text = page.get_text("text") # this grabs the text from each page of the CMU policy handbook PDF.
    cur_text_chunks = sentence_chunker(page_text, chunk_size=50, overlap=10) # Chunker Selection == word chunker. Change this in Section B of your homework.
    text_chunks.extend(cur_text_chunks)
    doc_idxs.extend([doc_idx] * len(cur_text_chunks))

# %%
# Define the query chosen for the experiment.
q2="How is cheating defined in the policy?"
q3="What is the policy for improper or illegal communications?"
q4="What are CMU’s quiet hours?"
q5= "Where are pets or animals allowed on CMU’s campus?"

# %%
# Encode the query for the experiment using the embedding model.
query_embedding = embedder.encode_documents([query])

# %%
# Search the vector store [varying the retrieved_numer (top_k) Parameter] and retrieve information from the store.
retrieved_number = 5
vs_search_results = query_collection(collection, q01_embeddings, n_results= retrieved_number)
print(f"Top {retrieved_number} search results:")
for i in range(retrieved_number):
    print(f"Result {i+1}:")
    print(f"Document ID: {vs_search_results['ids'][0][i]}")
    print(f"Document Text: {vs_search_results['documents'][0][i]}")
    print(f"Similarity Score: {1 - vs_search_results['distances'][0][i]:.4f}")
    print("-" * 50)
# Out:
# Top 5 search results:
# Result 1:
# Document ID: 1046
# Document Text: involving alleged violations of the University Policy on Academic Integrity, the following procedures apply:
# Similarity Score: 0.8346
# --------------------------------------------------
# Result 2:
# Document ID: 1032
# Document Text: of the University Policy on Academic Integrity including cheating, plagiarism, and unauthorized assistance. • Academic Integrity Liaison: Each department designates an individual who is trained by the Office of Community Standards and Integrity to provide guidance to course instructors in cases of alleged violations of the University Policy on Academic
# Similarity Score: 0.8067
# --------------------------------------------------
# Result 3:
# Document ID: 2360
# Document Text: academic integrity of our community. The Word provides a list of policies students are expected to uphold and the process by which violations will be addressed. Policies and procedures may be established or amended as necessary during the course of the academic year, which will become effective immediately upon notification
# Similarity Score: 0.7849
# --------------------------------------------------
# Result 4:
# Document ID: 106
# Document Text: when any student violates the University Policy on Academic Integrity including cheating, plagiarism and unauthorized assistance. Academic Integrity Policy Students at Carnegie Mellon are engaged in intellectual activity consistent with the highest standards of the academy. The relationship between students and instructors and their shared commitment to overarching standards of
# Similarity Score: 0.7623
# --------------------------------------------------
# Result 5:
# Document ID: 68
# Document Text: Integrity Academic integrity refers to the implicit commitment that every member makes to all others in the community to practice those principles that underlie the mission of the university and define academic integrity. These are: honesty and good faith; clarity in the communication of core values; professional conduct of work;
# Similarity Score: 0.7584
# --------------------------------------------------

# %%
# Save the input and output from the vector store.
input_output = {
    "query": query,
    "retrieved_number": retrieved_number,
    "results": [
        {
            "document_id": vs_search_results['ids'][0][i],
            "document_text": vs_search_results['documents'][0][i],
            "similarity_score": round(1 - vs_search_results['distances'][0][i], 4)
        }
        for i in range(retrieved_number)
    ]
}
with open("vector_store_results_sentence_chunker.json", "w") as f:
    json.dump(input_output, f, indent=2)
print("Saved vector store results to vector_store_results_sentence_chunker.json")
# Out:
# Saved vector store results to vector_store_results_sentence_chunker.json

# %% [markdown]
# ## *Experiment B.III: Using an Alternative Embedding Strategy.*

# %%
policy_questions = pd.read_csv('CMU_Handbook_1000_Questions.csv')
policy_questions
# Out:
#      Question Number                                            Section  \
# 0                  1     SECTION 1: VISION, MISSION & CMU CODE (Q1–Q25)
# 1                  2     SECTION 1: VISION, MISSION & CMU CODE (Q1–Q25)
# 2                  3     SECTION 1: VISION, MISSION & CMU CODE (Q1–Q25)
# 3                  4     SECTION 1: VISION, MISSION & CMU CODE (Q1–Q25)
# 4                  5     SECTION 1: VISION, MISSION & CMU CODE (Q1–Q25)
# ..               ...                                                ...
# 995              996  SECTION 20: STUDENT RESOURCES & MISCELLANEOUS ...
# 996              997  SECTION 20: STUDENT RESOURCES & MISCELLANEOUS ...
# 997              998  SECTION 20: STUDENT RESOURCES & MISCELLANEOUS ...
# 998              999  SECTION 20: STUDENT RESOURCES & MISCELLANEOUS ...
# 999             1000  SECTION 20: STUDENT RESOURCES & MISCELLANEOUS ...
#
#                                               Question  Document Embeddings
# 0    What is Carnegie Mellon University's stated vi...                  NaN
# 1    What are the three primary goals outlined in C...                  NaN
# 2    According to CMU's mission, what four areas of...                  NaN
# 3    What does the Carnegie Mellon Code state about...                  NaN
# 4    According to the CMU Code, what must students ...                  NaN
# ..                                                 ...                  ...
# 995  What is the policy on late submission of an in...                  NaN
# 996  What happens to a student's full-time status i...                  NaN
# 997  What is the role of the associate dean in gran...                  NaN
# 998  What is the general standard used by CMU's com...                  NaN
# 999  What are the core values articulated in Carneg...                  NaN
#
# [1000 rows x 4 columns]

# %%
policy_questions_embeddings = embedder.encode_queries(policy_questions['Question'].to_list())

# %%
# save the policy question dataset embeddings:
#save_embeddings(policy_questions_embeddings, path="policy_question_dataset_embeddings.json")
save_embeddings({"dense": policy_questions_embeddings, "sparse": []}, path="policy_question_dataset_embeddings.json")
# Out:
# Saved to policy_question_dataset_embeddings.json

# %%
policy_questions_embeddings = load_embeddings("policy_question_dataset_embeddings.json")

# %%
matched = match_questions_to_documents(
    questions=policy_questions['Question'].to_list(),               # list of 1000 question strings
    question_embeddings=policy_questions_embeddings,
    collection=collection,             # your ChromaDB collection
    docs=docs,                         # your original document list
    n_results=1,                       # top-N docs per question
    save_path="question_doc_chunk_matches.json"
)
# Out:
# Querying 1000 questions against 2615 documents...
# Saved 1000 matches to question_doc_chunk_matches.json
# Saved plot to question_doc_distribution.png
#
# ── Summary ──────────────────────────────
# Total questions:       1000
# Unique docs matched:   639
# Most matched doc:      ('1416', 10)
# Avg similarity score:  0.6819
# Min similarity score:  0.3007
# Max similarity score:  0.9247

# %%
print(matched[0])
# Out:
# {'question_id': 0, 'question': "What is Carnegie Mellon University's stated vision as described in the Student Handbook?", 'matched_document': 'educates its students to become professionals who will serve society with integrity. The university also creates and disseminates new knowledge and expressions of knowledge in ways that benefit society. Carnegie Mellon strives to serve the changing needs of society through the three primary goals outlined in its mission statement: to', 'matched_doc_id': '56', 'similarity_score': 0.6736}

# %%
# Remake the vector store using the new embeddings that were created with the Policy Question Dataset.
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Define the query chosen for the experiment.
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Encode the queryfor the experiment using the embedding model.
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Search the vector store [varying the retrieved_numer (top_k) Parameter] and retrieve information from the store.
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Save the input and output from the vector store.
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# # **Section C: Evaluation.**

# %% [markdown]
# ## *Design an LLM Judge to Produce Custom Metrics*
#
# **Tasks:**
# > [1] Using a Pydantic Base Model technique, design an LLM Judge to automatically score the quality of the vector store responses with respect to the query submitted to the store AND a specific characteristics of the text; for example: factuality, relevance, specificity, helpfulness.
#
# > [2] Measure the quality of the information retrieval using the LLM Judge.

# %%
#Use Claude instead of HuggingFace for LLM evaluation
import os, re
from anthropic import Anthropic
# Use Claude for LLM evaluation

eval_result = evaluate_relevance_claude(
    question=matched[0]["question"],
    question_id=matched[0]["question_id"],
    matched_docs=matched[:3],
    api_key=ANTHROPIC_API_KEY,
    model_id="claude-sonnet-4-6"
)

print(f"Overall: {eval_result.overall_score.name} ({eval_result.overall_score})")
print(f"Mean:    {eval_result.mean_score:.2f}")
print(f"Distribution: {eval_result.score_distribution}")
# Out:
# Overall: DISAGREE (2)
# Mean:    2.33
# Distribution: {'STRONGLY_DISAGREE': 1, 'DISAGREE': 0, 'NEUTRAL': 2, 'AGREE': 0, 'STRONGLY_AGREE': 0}

# %%
print(eval_result.token_usage)
#TokenUsage(model_id='Qwen/Qwen2.5-72B-Instruct', input_tokens=312, output_tokens=87, total_tokens=399, cost_usd=0.00019)
# Out:
# model_id='claude-sonnet-4-6' input_tokens=511 output_tokens=556 total_tokens=1067 cost_usd=9.87e-06 cost_per_1m_in=0.003 cost_per_1m_out=0.015

# %% [markdown]
# ## *Metric Selection: Precision and Recall*
#
# **Tasks:**
# > [1] Select evaluation metrics to assess the quality of the information retrieved from the vector store.
#
# > [2] Measure the quality of the information retrieval using the evaluation metrics that you chose.

# %%
# First collect eval results for all your questions
eval_results = []
for q in matched[:5]:  # run on however many you've evaluated
    result = evaluate_relevance_claude(
        question=q["question"],
        question_id=q["question_id"],
        matched_docs=[q],
        api_key=ANTHROPIC_API_KEY,
        model_id="claude-sonnet-4-6"
    )
    eval_results.append(result)

# Then measure precision/recall
summary = evaluate_precision_recall(
    matched=matched,
    eval_results=eval_results,
    relevance_threshold=LikertScore.STRONGLY_AGREE  # count score > 4 as relevant
)
# Out:
# ── Summary (threshold ≥ STRONGLY_AGREE) ─────────────────
# Macro  Precision: 0.2000  Recall: 0.2000  F1: 0.2000
# Micro  Precision: 0.2000  Recall: 1.0000  F1: 0.3333

# %% [markdown]
# # **Section D: Write a report providing your experimental results (from Sections: A, B and C), detailing your experimental design, methodology, and assessments of the quality of the information retrieval from the two distinct Vector Stores.**

# %%
# Homework Questions List: https://docs.google.com/document/d/1-TF9NjdrTxvkTDzK4BS2tSGuodKEvNClaEsWoPsfKMc/edit?usp=sharing
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
